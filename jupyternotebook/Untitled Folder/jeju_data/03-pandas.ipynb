# %%
import pandas as pd

# %%
import numpy as np
df = pd.DataFrame(
        {"a" : [4 ,5, 6, 6, 6],
        "b" : [7, 8, 9, 9, 9],
        "c" : [10, 11, 12, 12, 12]},
        index = pd.MultiIndex.from_tuples(
        [('d',1),('d',2),('e',2),('e',3),('e',4)],
        names=['n','v']))
df
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12
#   3  6  9  12
#   4  6  9  12

# %%
df[df.a < 7]
# 비교연산자
# df.b > 7
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12
#   3  6  9  12
#   4  6  9  12

# %%
df['c'] > 7
# Out:
# n  v
# d  1    True
#    2    True
# e  2    True
#    3    True
#    4    True
# Name: c, dtype: bool

# %%
df[df['c'] != 7]
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12
#   3  6  9  12
#   4  6  9  12

# %%
df
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12
#   3  6  9  12
#   4  6  9  12

# %%
df = df.drop_duplicates(keep='last')
# 킵 래스트해줘야 유지된다.
df
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 4  6  9  12

# %%
df
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 4  6  9  12

# %%
import numpy as np
df = pd.DataFrame(
        {"a" : [4 ,5, 6, 6, 6],
        "b" : [7, 8, 9, 9, 9],
        "c" : [10, 11, 12, 12, 12]},
        index = pd.MultiIndex.from_tuples(
        [('d',1),('d',2),('e',2),('e',3),('e',4)],
        names=['n','v']))

# %%
df
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12
#   3  6  9  12
#   4  6  9  12

# %%
df["a"] != 7
# Out:
# n  v
# d  1    True
#    2    True
# e  2    True
#    3    True
#    4    True
# Name: a, dtype: bool

# %%
df[df["a"] != 7]
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12
#   3  6  9  12
#   4  6  9  12

# %%
df.a.isin([5, 6])
# Out:
# n  v
# d  1    False
#    2     True
# e  2     True
#    3     True
#    4     True
# Name: a, dtype: bool

# %%
df[df['a'].isin([5, 6])]
# Out:
#      a  b   c
# n v
# d 2  5  8  11
# e 2  6  9  12
#   3  6  9  12
#   4  6  9  12

# %%
import numpy as np
df = pd.DataFrame(
        {"a" : [4 ,5, 6, 6, 6],
        "b" : [7, 8, 9, 9, 9],
        "c" : [10, 11, 12, 12, 12]},
        index = pd.MultiIndex.from_tuples(
        [('d',1),('d',2),('e',2),('e',3),('e',4)],
        names=['n','v']))
df
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12
#   3  6  9  12
#   4  6  9  12

# %%
pd.isnull(df)
# Out:
#          a      b      c
# n v
# d 1  False  False  False
#   2  False  False  False
# e 2  False  False  False
#   3  False  False  False
#   4  False  False  False

# %%
pd.isnull(df).sum()
# Out:
# a    0
# b    0
# c    0
# dtype: int64

# %%
pd.notnull(df)
# Out:
#         a     b     c
# n v
# d 1  True  True  True
#   2  True  True  True
# e 2  True  True  True
#   3  True  True  True
#   4  True  True  True

# %%
df.notnull()
# Out:
#         a     b     c
# n v
# d 1  True  True  True
#   2  True  True  True
# e 2  True  True  True
#   3  True  True  True
#   4  True  True  True

# %%
df.notnull()
# Out:
# a    5
# b    5
# c    5
# dtype: int64

# %%
df.a.notnull().sum()
# Out:
# 5

# %%
df.any()
# Out:
# a    True
# b    True
# c    True
# dtype: bool

# %%
df.all
# Out:
# <bound method DataFrame.all of      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12
#   3  6  9  12
#   4  6  9  12>

# %%
~df.a.notnull()
# Out:
# n  v
# d  1    False
#    2    False
# e  2    False
#    3    False
#    4    False
# Name: a, dtype: bool

# %%
df
# Out:
#      a  b   c
# n v
# d 1  4  7  10
#   2  5  8  11
# e 2  6  9  12
#   3  6  9  12
#   4  6  9  12

# %%
df[df.a == 7]  ==
# Out:
# Empty DataFrame
# Columns: [a, b, c]
# Index: []

# %%
df[df.b == 5]
# Out:
# Empty DataFrame
# Columns: [a, b, c]
# Index: []

# %%
df[df[df.a == 5] | df[df.b == 7]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     265         #  (xint or xbool) and (yint or bool)
# --> 266         result = op(x, y)
#     267     except TypeError:
#
# TypeError: unsupported operand type(s) for |: 'float' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-7acb2f152dd7> in <module>()
# ----> 1 df[df[df.a == 5] | df[df.b == 7]]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/__init__.py in f(self, other, axis, level, fill_value)
#     653         if isinstance(other, ABCDataFrame):
#     654             # Another DataFrame
# --> 655             new_data = self._combine_frame(other, na_op, fill_value)
#     656
# ...
