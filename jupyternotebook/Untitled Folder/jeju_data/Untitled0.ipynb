# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(
    {"a" : [4, 5, 6, 6, np.nan],
     "b" : [7, 8, np.nan, 9, 9],
     "c" : [10, 11, 12, np.nan, 12]},
     index = pd.MultiIndex.from_tuples(
         [('d',1),('d',2),('e',2),('e',3),('e',4)],
         names=['n', 'v']))
df
# Out:
#        a    b     c
# n v
# d 1  4.0  7.0  10.0
#   2  5.0  8.0  11.0
# e 2  6.0  NaN  12.0
#   3  6.0  9.0   NaN
#   4  NaN  9.0  12.0

# %%
df.head(3)
# Out:
#        a    b     c
# n v
# d 1  4.0  7.0  10.0
#   2  5.0  8.0  11.0
# e 2  6.0  NaN  12.0

# %%
df.sample(frac=0.3)
# Out:
#        a    b     c
# n v
# e 2  6.0  NaN  12.0
# d 2  5.0  8.0  11.0

# %%
df.sample(n=4)
# Out:
#        a    b     c
# n v
# e 2  6.0  NaN  12.0
#   4  NaN  9.0  12.0
#   3  6.0  9.0   NaN
# d 1  4.0  7.0  10.0
